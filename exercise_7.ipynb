# %% [markdown]
# <a href="https://colab.research.google.com/github/pranathikrovvidi-del/Python-Programs/blob/main/exercise_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SETS IN PYTHON

# %%
#set operations
a={1,2,3,4}
b={4,5,6,7}
print("Union:",a|b)
print("Intersection:",a&b)
print("Difference:",a-b)
print("Symmetric Difference:",a^b)
# Out:
# Union: {1, 2, 3, 4, 5, 6, 7}
# Intersection: {4}
# Difference: {1, 2, 3}
# Symmetric Difference: {1, 2, 3, 5, 6, 7}

# %%
#set methods
a={1,2,3,4}
b={5,6,7,8}
a.add(5)
print("After add:",a)
a.remove(2)
print("After remove:",a)
a.discard(3)
print("After discard:",a)
a.update({6,7})
print("After update:",a)
print("Difference:",a.difference(b))
print("Symmetric difference:",a.symmetric_difference(b))
# Out:
# After add: {1, 2, 3, 4, 5}
# After remove: {1, 3, 4, 5}
# After discard: {1, 4, 5}
# After update: {1, 4, 5, 6, 7}
# Difference: {1, 4}
# Symmetric difference: {1, 4, 8}
